# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_excel("C:/Users/Administrator/Downloads/Mo _ Payment Behaviour 12 months.xlsx")
df1.head(5)
# Out:
#                                             loanuuid  Loan Price  Deposit  \
# 0  26509775439ac1a56e030c90682e548faf25c7d5ccd59e...       44479   5999.0
# 1  fce68cb693e32deab48f290431364fd0b44d052d143cdb...      100439  10999.0
# 2  0c2bfb54a24fcc68df192fe288fcd27fffce3b7b97e3ea...       61079   6999.0
# 3  405a7de6b754b854b0f1db19db2b86144fa32d0eb5718f...       42459   4499.0
# 4  729f240510b918934bf76f126cb4a9f54d0638633398f0...       69879   7999.0
#
#    Weekly Rate Month Sale Date Month Paid Off Date  Due Eomth01  \
# 0        740.0      2023-10-01                 NaT          NaN
# 1       1720.0      2024-07-01                 NaT          NaN
# 2       1040.0      2023-06-01          2023-06-01      13239.0
# 3        730.0      2024-06-01                 NaT          NaN
# 4       1190.0      2023-09-01                 NaT          NaN
#
#    Totpaid Eomth01  Due Eomth02  Totpaid Eomth02  ...  Due Eomth08  \
# ...

# %%
from scipy import stats

# %%
# Basic Statistics Check (mean, median, mode, standard deviation)
def basic_statistics_check(df1):
    summary_stats = pd.DataFrame({
        'Mean': df1.mean(),
        'Median': df1.median(),
        'Mode': df1.mode().iloc[0],  # Mode may return multiple values, take the first
        'Standard Deviation': df.std(),
        'Min': df1.min(),
        'Max': df1.max(),
        '25th Percentile': df1.quantile(0.25),
        '75th Percentile': df1.quantile(0.75)
    })
    
    return summary_stats

# %%
# Data Type and Format Consistency
def check_data_types(df):
    return df.dtypes

def check_date_format(df, date_column):
    # Check for invalid dates in a column
    try:
        df[date_column] = pd.to_datetime(df[date_column], errors='coerce')
        invalid_dates = df[date_column].isna().sum()
        return invalid_dates
    except Exception as e:
        return str(e)

# %%
df1.describe()
# Out:
#           Loan Price       Deposit  Weekly Rate  \
# count    5187.000000   5183.000000  5183.000000
# mean    68299.162329   8626.366390  1148.263554
# min        -1.000000     -1.000000     0.000000
# 25%     45559.000000   5499.000000   780.000000
# 50%     67199.000000   7999.000000  1130.000000
# 75%     80259.000000   9999.000000  1350.000000
# max    334219.000000  55499.000000  5360.000000
# std     27396.551886   4664.610351   444.485091
#
#                      Month Sale Date            Month Paid Off Date  \
# count                           5183                            349
# mean   2024-02-06 02:25:51.688211456  2024-03-16 00:24:45.386819584
# min              2023-02-01 00:00:00            2023-02-01 00:00:00
# 25%              2023-11-01 00:00:00            2024-02-01 00:00:00
# 50%              2024-03-01 00:00:00            2024-05-01 00:00:00
# 75%              2024-06-01 00:00:00            2024-06-01 00:00:00
# ...

# %%
df1.isnull().sum()
# Out:
# loanuuid                  0
# Loan Price                0
# Deposit                   4
# Weekly Rate               4
# Month Sale Date           4
# Month Paid Off Date    4838
# Due Eomth01            4872
# Totpaid Eomth01        4855
# Due Eomth02            4728
# Totpaid Eomth02        4712
# Due Eomth03            4441
# Totpaid Eomth03        4428
# Due Eomth04            4138
# Totpaid Eomth04        4125
# Due Eomth05            3834
# Totpaid Eomth05        3820
# Due Eomth06            3424
# Totpaid Eomth06        3408
# Due Eomth07            3186
# Totpaid Eomth07        3171
# Due Eomth08            2861
# Totpaid Eomth08        2846
# Due Eomth09            2420
# Totpaid Eomth09        2409
# Due Eomth10            1895
# Totpaid Eomth10        1883
# Due Eomth11            1323
# Totpaid Eomth11        1317
# Due Eomth12             672
# Totpaid Eomth12         677
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df2 = pd.read_excel("C:/Users/Administrator/Downloads/Mo _ CSAT Calls.xlsx")
df2.head(5)
# Out:
#                  Created Time  \
# 0  2023-09-20 21:19:49.000000
# 1  2023-09-20 21:26:17.000000
# 2  2023-09-20 21:32:15.000000
# 3  2023-09-20 21:33:17.000000
# 4  2023-09-20 21:35:39.000000
#
#                                             loanuuid  \
# 0  edc2d0b162ea098590538b202a6408e2aaa0915f264950...
# 1  d2a96f122ce74730d91faa598f40cadeb4b83d20d40236...
# 2  b8d094de5caeec806fd97309ecbf9556f37b06f3b2618f...
# 3  cc5a74e2836a56e9fa72c3ffe37bc83859855f4c097351...
# 4  5ad84783f3197ea1ba24398d09626120091f0e6f527dd7...
#
#                      Contact Disposition  \
# 0   Reached and talked to customer - RPC
# 1   Reached and talked to customer - RPC
# 2   Reached and talked to customer - RPC
# 3  Phone switched off  No Answer machine
# 4  Phone switched off  No Answer machine
#
#                     Service Request Status          Whatsapp Csat  \
# 0  No , I have never requested for Service  Yes and was satisfied
# ...

# %%
df2.describe()
# Out:
#         Nps Score  Old Csat X  Old Csat Y
# count  111.000000         0.0         0.0
# mean     6.207207         NaN         NaN
# std      3.314204         NaN         NaN
# min      0.000000         NaN         NaN
# 25%      5.000000         NaN         NaN
# 50%      7.000000         NaN         NaN
# 75%      9.000000         NaN         NaN
# max     10.000000         NaN         NaN

# %%
df2.isnull().sum()
# Out:
# Created Time                0
# loanuuid                    0
# Contact Disposition         0
# Service Request Status    224
# Whatsapp Csat             224
# Ease Of Contact           300
# Overall Csat              300
# Unsatisfied Components    224
# Unsatisfied Services      224
# Feedback Notes            237
# Nps Score                 445
# Ces Score                 445
# Sale Process Csat         516
# Delivery Process Csat     516
# Product Csat              516
# Ussd Csat                 555
# Old Csat X                556
# Old Csat Y                556
# dtype: int64

# %%
df1.dtypes
# Out:
# loanuuid                       object
# Loan Price                      int64
# Deposit                       float64
# Weekly Rate                   float64
# Month Sale Date        datetime64[ns]
# Month Paid Off Date    datetime64[ns]
# Due Eomth01                   float64
# Totpaid Eomth01               float64
# Due Eomth02                   float64
# Totpaid Eomth02               float64
# Due Eomth03                   float64
# Totpaid Eomth03               float64
# Due Eomth04                   float64
# Totpaid Eomth04               float64
# Due Eomth05                   float64
# Totpaid Eomth05               float64
# Due Eomth06                   float64
# Totpaid Eomth06               float64
# Due Eomth07                   float64
# Totpaid Eomth07               float64
# Due Eomth08                   float64
# Totpaid Eomth08               float64
# Due Eomth09                   float64
# Totpaid Eomth09               float64
# Due Eomth10                   float64
# ...

# %%
df2.dtypes
# Out:
# Created Time               object
# loanuuid                   object
# Contact Disposition        object
# Service Request Status     object
# Whatsapp Csat              object
# Ease Of Contact            object
# Overall Csat               object
# Unsatisfied Components     object
# Unsatisfied Services       object
# Feedback Notes             object
# Nps Score                 float64
# Ces Score                  object
# Sale Process Csat          object
# Delivery Process Csat      object
# Product Csat               object
# Ussd Csat                  object
# Old Csat X                float64
# Old Csat Y                float64
# dtype: object

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df = pd.merge(df1, df2, on='loanuuid', how='inner')

# Display the first few rows of the merged dataframe
df.head()
# Out:
#                                             loanuuid  Loan Price  Deposit  \
# 0  b5e1c4a61cf0f2be5393d3f2ed1bf5aca6e73d540e1635...       67739   9499.0
# 1  56a1b63ea0eac472bb8ddf31fddb0eff61b94d18b47056...       71359   9999.0
# 2  3aa65028fabe504636777b5634590d23849ef966fbd090...      171399  30999.0
# 3  61158efb34f8c5fb2a54c0768e6fc3368937a7d2e72038...       54239   8999.0
# 4  6941f518e288388168fb2f3397a9ad28cb77c4a4bee13f...       39339   4499.0
#
#    Weekly Rate Month Sale Date Month Paid Off Date  Due Eomth01  \
# 0       1120.0      2023-09-01                 NaT          NaN
# 1       1180.0      2024-01-01                 NaT          NaN
# 2       2700.0      2024-07-01                 NaT          NaN
# 3        870.0      2023-09-01                 NaT          NaN
# 4        670.0      2023-10-01                 NaT          NaN
#
#    Totpaid Eomth01  Due Eomth02  Totpaid Eomth02  ...  Unsatisfied Services  \
# ...

# %%
df.describe()
# Out:
#           Loan Price       Deposit  Weekly Rate  \
# count     321.000000    321.000000   321.000000
# mean    65312.084112   8784.358255  1087.071651
# min     33119.000000   3999.000000   560.000000
# 25%     44479.000000   5999.000000   740.000000
# 50%     57399.000000   7999.000000   950.000000
# 75%     81199.000000  10999.000000  1340.000000
# max    204699.000000  33999.000000  3350.000000
# std     27455.620295   4664.065147   442.427421
#
#                      Month Sale Date  Month Paid Off Date   Due Eomth01  \
# count                            321                   32     42.000000
# mean   2023-09-08 06:07:51.028037376  2024-04-10 11:15:00  10351.857143
# min              2023-07-01 00:00:00  2023-10-01 00:00:00   4999.000000
# 25%              2023-08-01 00:00:00  2024-02-01 00:00:00   6479.000000
# 50%              2023-09-01 00:00:00  2024-06-01 00:00:00   6739.000000
# 75%              2023-10-01 00:00:00  2024-07-01 00:00:00  12579.000000
# ...

# %%
df.columns
# Out:
# Index(['loanuuid', 'Loan Price', 'Deposit', 'Weekly Rate', 'Month Sale Date',
#        'Month Paid Off Date', 'Due Eomth01', 'Totpaid Eomth01', 'Due Eomth02',
#        'Totpaid Eomth02', 'Due Eomth03', 'Totpaid Eomth03', 'Due Eomth04',
#        'Totpaid Eomth04', 'Due Eomth05', 'Totpaid Eomth05', 'Due Eomth06',
#        'Totpaid Eomth06', 'Due Eomth07', 'Totpaid Eomth07', 'Due Eomth08',
#        'Totpaid Eomth08', 'Due Eomth09', 'Totpaid Eomth09', 'Due Eomth10',
#        'Totpaid Eomth10', 'Due Eomth11', 'Totpaid Eomth11', 'Due Eomth12',
#        'Totpaid Eomth12', 'Created Time', 'Contact Disposition',
#        'Service Request Status', 'Whatsapp Csat', 'Ease Of Contact',
#        'Overall Csat', 'Unsatisfied Components', 'Unsatisfied Services',
#        'Feedback Notes', 'Nps Score', 'Ces Score', 'Sale Process Csat',
#        'Delivery Process Csat', 'Product Csat', 'Ussd Csat', 'Old Csat X',
#        'Old Csat Y'],
#       dtype='object')

# %%
non_numeric_columns = df_relevant.select_dtypes(include=['object']).columns
print(non_numeric_columns)
# Out:
# Index(['Whatsapp Csat', 'Ease Of Contact', 'Overall Csat', 'Ces Score',
#        'Sale Process Csat', 'Delivery Process Csat', 'Product Csat',
#        'Ussd Csat'],
#       dtype='object')

# %%
df_numeric = df_relevant.select_dtypes(include=[float, int])

# %%
from sklearn.preprocessing import LabelEncoder

label_encoders = {}
for column in non_numeric_columns:
    le = LabelEncoder()
    df_relevant[column] = le.fit_transform(df_relevant[column].astype(str))
    label_encoders[column] = le

# %%
correlation_matrix = df_numeric.corr()

# %%
# Plot heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap: Payment Metrics and Satisfaction Scores')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
df['Diff_Eomth01'] = df['Totpaid Eomth01'] - df['Due Eomth01']
df['Diff_Eomth02'] = df['Totpaid Eomth02'] - df['Due Eomth02']
df['Diff_Eomth03'] = df['Totpaid Eomth03'] - df['Due Eomth03']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.lineplot(data=df[['Diff_Eomth01', 'Diff_Eomth02', 'Diff_Eomth03', 'Nps Score']])
plt.title("Payment Differences Over 3 Months vs NPS Score")
plt.xlabel("Data Points")
plt.ylabel("Amount Differences (Paid - Due) / NPS Score")
plt.legend(["Diff_Eomth01", "Diff_Eomth02", "Diff_Eomth03", "Nps Score"])
plt.grid(True)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Plot 2: NPS Score Distribution
plt.figure(figsize=(8, 6))
sns.histplot(df['Nps Score'], bins=10, kde=True)
plt.title("NPS Score Distribution")
plt.xlabel("NPS Score")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Plot 3: Payment Differences by Month
plt.figure(figsize=(10, 6))
df[['Diff_Eomth01', 'Diff_Eomth02', 'Diff_Eomth03']].plot(kind='bar', stacked=False)
plt.title("Payment Differences by Month")
plt.xlabel("Data Points")
plt.ylabel("Amount Differences (Paid - Due)")
plt.legend(["Diff_Eomth01", "Diff_Eomth02", "Diff_Eomth03"])
plt.grid(True)
plt.show()
